# %% [markdown]
# # INICIANDO O ESTUDO DO PANDAS

# %% [markdown]
# ## Importando a Base de Dados

# %%
import pandas as pd

# %%
pd.read_csv('dados/aluguel.csv')
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# 5               Apartamento;Vista Alegre;3;1;0;70;1200;;
# 6              Apartamento;Cachambi;2;0;0;50;1300;301;17
# 7      Casa de Condomínio;Barra da Tijuca;5;4;5;750;2...
# 8               Casa de Condomínio;Ramos;2;2;0;65;1000;;
# 9      Conjunto Comercial/Sala;Centro;0;3;0;695;35000...
# 10                    Apartamento;Centro;1;0;0;36;1200;;
# 11               Apartamento;Grajaú;2;1;0;70;1500;642;74
# 12     Apartamento;Lins de Vasconcelos;3;1;1;90;1500;...
# 13           Apartamento;Copacabana;1;0;1;40;2000;561;50
# 14               Quitinete;Copacabana;1;0;0;27;1800;501;
# ...

# %%
##Alterando o delimitador do notebok
dados = pd.read_csv('dados/aluguel.csv', sep = ';')
##Para verificar o tipo de variavel
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
##Para mostrar os tipos de dados
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
# Tipo          32960 non-null object
# Bairro        32960 non-null object
# Quartos       32960 non-null int64
# Vagas         32960 non-null int64
# Suites        32960 non-null int64
# Area          32960 non-null int64
# Valor         32943 non-null float64
# Condominio    28867 non-null float64
# IPTU          22723 non-null float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
##Para mostrar parte da grid. Com Tail mostra os ultimos
dados.head(5)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
## Para executar todas as celulas é só ir em 'Cell' -> 'Run All'

# %% [markdown]
# ## Informações Gerais sobre o DataSet

# %%
dados.dtypes
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
## Criando um DataFrame
dfTiposDados = pd.DataFrame(dados.dtypes, columns = ['Tipos de Dados'])
dfTiposDados.columns.name = 'Variaveis'

# %%
dfTiposDados
# Out:
# Variaveis  Tipos de Dados
# Tipo               object
# Bairro             object
# Quartos             int64
# Vagas               int64
# Suites              int64
# Area                int64
# Valor             float64
# Condominio        float64
# IPTU              float64

# %%
## Para a qtd de linha e de colunas
dados.shape
# Out:
# (32960, 9)

# %%
print('O dataset apresenta {} registros (imoveis) e {} tipos de variáveis'.format(dados.shape[0], dados.shape[1]) )
# Out:
# O dataset apresenta 32960 registros (imoveis) e 9 tipos de variáveis
